# %% [markdown]
# <a href="https://colab.research.google.com/github/jordanco-bgu/social_network_movies/blob/main/Social_network_attributes_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Social Network Attributes Dataset
#
# Parsing and defining attributes of the social networks created by Kagan, Dima, Thomas Chesney, and Michael Fire in their study "Using data science to understand the film industry's gender gap." Data was found on Kaggle in .json files where each file represented the social network of a singular movie.
#
# Notes on how the social networks were constructed:
# * links between characters were created if they appeared in the movie in a time interval of less than 60 seconds
# * for each appearance, the weight of the edge between them was increased by 1
# * all edges with weight lower than 3 were filtered out to account for possible mistakes

# %%
import json
import os

# !pip install kaggle

api_token = {"username":"","key":""}

# !mkdir /root/.kaggle
with open('/root/.kaggle/kaggle.json', 'w') as file:
  json.dump(api_token, file)
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.16)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)

# %%
# !mkdir ./datasets
# !mkdir ./datasets/movie-dynamics-networks

# !kaggle datasets download michaelfire/movie-dynamics-over-15000-movie-social-networks -p ./datasets/movie-dynamics-networks
# !unzip ./datasets/movie-dynamics-networks/*.zip  -d ./datasets/movie-dynamics-networks/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cub.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cub.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cuban_Fury.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cuban_Fury.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cut_Bank.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cut_Bank.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cut_Snake.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cut_Snake.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cymbeline.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Cymbeline.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Da_Sweet_Blood_of_Jesus.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Da_Sweet_Blood_of_Jesus.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Daawat_e_Ishq.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Daawat_e_Ishq.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dancing_Arabs.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dancing_Arabs.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dark_Was_the_Night.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dark_Was_the_Night.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Date_and_Switch.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Date_and_Switch.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dawn_of_the_Planet_of_the_Apes.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dawn_of_the_Planet_of_the_Apes.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dead_Snow_2_Red_vs_Dead.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dead_Snow_2_Red_vs_Dead.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dear_White_People.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dear_White_People.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Death_in_Buenos_Aires.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Death_in_Buenos_Aires.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Debug.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Debug.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dedh_Ishqiya.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dedh_Ishqiya.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Deep_in_the_Darkness.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Deep_in_the_Darkness.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Deepsea_Challenge_3D.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Deepsea_Challenge_3D.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Der_kleine_Drache_Kokosnuss.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Der_kleine_Drache_Kokosnuss.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Desert_Dancer.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Desert_Dancer.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Devil_s_Due.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Devil_s_Due.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dig_Two_Graves.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dig_Two_Graves.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Digging_Up_the_Marrow.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Digging_Up_the_Marrow.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dinosaur_13.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dinosaur_13.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Diplomacy.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Diplomacy.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Divergent.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Divergent.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dolphin_Tale_2.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dolphin_Tale_2.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dr_Cabbie.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dr_Cabbie.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dracula_Untold.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dracula_Untold.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Draft_Day.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Draft_Day.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Drive_Hard.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Drive_Hard.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Drushyam.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Drushyam.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dumb_and_Dumber_To.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dumb_and_Dumber_To.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dying_of_the_Light.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Dying_of_the_Light.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Earth_to_Echo.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Earth_to_Echo.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_East_Side_Sushi.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_East_Side_Sushi.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Eat_with_Me.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Eat_with_Me.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Echoes.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Echoes.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Edge_of_Tomorrow.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Edge_of_Tomorrow.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Effie_Gray.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Effie_Gray.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Ejecta.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Ejecta.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_El_Nin_o.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_El_Nin_o.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Electricity.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Electricity.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_Elephant_Song.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2014_
actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_The_Wild_Pear_Tree.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_The_World_Is_Yours.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_The_World_Is_Yours.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Three_Identical_Strangers.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Three_Identical_Strangers.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Thunder_Road.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Thunder_Road.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_To_All_the_Boys_I_ve_Loved_Before.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_To_All_the_Boys_I_ve_Loved_Before.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Tomb_Raider.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Tomb_Raider.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Traffik.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Traffik.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Truth_or_Dare.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Truth_or_Dare.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Tully.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Tully.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_UFO.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_UFO.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Uncle_Drew.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Uncle_Drew.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Under_the_Silver_Lake.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Under_the_Silver_Lake.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Unfriended_Dark_Web.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Unfriended_Dark_Web.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Unsane.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Unsane.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Upgrade.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Upgrade.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Vada_Chennai.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Vada_Chennai.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Venom.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Venom.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_What_Keeps_You_Alive.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_What_Keeps_You_Alive.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_When_We_First_Met.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_When_We_First_Met.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_White_Boy_Rick.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_White_Boy_Rick.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Whitney.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Whitney.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Widows.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Widows.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Wildlife.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Wildlife.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Wildling.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Wildling.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Winchester.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Winchester.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Won_t_You_Be_My_Neighbor.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Won_t_You_Be_My_Neighbor.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Zoe.actors.json
#   inflating: ./datasets/movie-dynamics-networks/moviedynamics/2018_Zoe.json

# %%
def get_network_strength(edges):
  total_weight = 0

  for edge in edges:
    total_weight = total_weight + edge['weight']

  return total_weight

def get_edge_with_max_weight(edges):
  max_weight = 0
  max_edge_source = None
  max_edge_target = 0

  for edge in edges:
    if edge['weight'] > max_weight:
      max_weight = edge['weight']
      max_edge_source = edge['source']
      max_edge_target = edge['target']

  return max_weight, max_edge_source, max_edge_target

# %%
def create_edges_list(network_file):
  sources_list = []
  targets_list = []
  edges_list = []

  for link in network_file['links']:
    sources_list.append(link['source'])
    targets_list.append(link['target'])

  edges_list = list(zip(sources_list, targets_list))
  return edges_list

# %%
import networkx as nx

def get_connected_components(graph):
  return nx.number_connected_components(graph)

def get_main_characters(graph):
  main_characters_list = []
  centrality_threshold = 0.6

  degree_central_characters = dict(sorted(nx.degree_centrality(graph).items(), key=lambda x:x[1], reverse=True))
  for character in degree_central_characters.items():
    if character[1] > centrality_threshold:
      main_characters_list.append(character[0])

  return len(main_characters_list)

def get_node_with_max_degree(graph):
  max_degree = 0
  max_node = None

  node_degree_list = list(graph.degree())

  for item in node_degree_list:
    if item[1] > max_degree:
      max_degree = item[1]
      max_node = item[0]

  return max_degree, max_node

def run_graph_algos(movie_network_file):

  edges_list = create_edges_list(movie_network_file)
  movie_graph = nx.Graph(edges_list)

  cc = get_connected_components(movie_graph)
  num_main_characters = get_main_characters(movie_graph)
  max_degree, max_degree_node = get_node_with_max_degree(movie_graph)
  return cc, num_main_characters, max_degree, max_degree_node

# %%
def get_attributes_from_json(filename):
  attributes = {}

  with open(filename,'r') as json_file :
    movie_network_file = json.load(json_file)

  attributes['movie_name'] = movie_network_file['graph']['movie_name']
  attributes['year'] = movie_network_file['graph']['movie_year']

  attributes['num_characters'] = len(movie_network_file['nodes'])
  attributes['num_connections'] = len(movie_network_file['links'])

  attributes['num_connected_components'], attributes['num_main_characters'], attributes['max_degree_node_value'], attributes['max_degree_node'] = run_graph_algos(movie_network_file)

  attributes['network_strength'] = get_network_strength(movie_network_file['links'])
  attributes['max_weight_edge_value'], attributes['max_weight_edge_source'], attributes['max_weight_edge_target'] = get_edge_with_max_weight(movie_network_file['links'])

  return attributes

# %%
import glob
import pandas as pd

files_list = []

for i in filter(lambda x: not ('.actors.' in x), glob.glob('./datasets/movie-dynamics-networks/moviedynamics/*')):
    files_list.append(i)

social_network_data = []

for json_file in files_list:
  attributes = get_attributes_from_json(json_file)
  social_network_data.append(attributes)

social_network_df = pd.DataFrame(social_network_data)
social_network_df
# Out:
#                         movie_name  year  num_characters  num_connections  \
# 0                    Inherent Vice  2014              35              154
# 1                   The Ladies Man  1961               8               12
# 2      Salmon Fishing in the Yemen  2011              10               27
# 3                 American Samurai  1992               5                6
# 4           A Prayer for the Dying  1987              15               27
# ...                            ...   ...             ...              ...
# 15533                 Bottle Shock  2008              18               47
# 15534                     Mankatha  2011               8               14
# 15535               Righteous Kill  2008              17               46
# 15536                       Angoor  1982               9               19
# 15537                Summer's Moon  2009               9               12
#
#        num_connected_components  num_main_characters  max_degree_node_value  \
# 0                             1                    3                     32
# 1                             1                    1                      7
# 2                             1                    6                      9
# 3                             1                    2                      4
# 4                             1                    2                     11
# ...                         ...                  ...                    ...
# 15533                         1                    1                     14
# 15534                         1                    3                      5
# 15535                         1                    1                     15
# 15536                         1                    3                      8
# 15537                         1                    2                      8
#
#                          max_degree_node  network_strength  \
# 0                  Larry "Doc" Sportello              2363
# 1      Herbert H. Heebert - Mama Heebert               173
# 2                       Dr. Alfred Jones               267
# 3                  Andrew 'Drew' Collins                50
# 4                            Jack Meehan               224
# ...                                  ...               ...
# 15533                         Bo Barrett               410
# 15534                             Ganesh                87
# 15535                               Turk               570
# 15536                            Bahadur               177
# 15537                          Tom Hoxey               104
#
#        max_weight_edge_value             max_weight_edge_source  \
# 0                        220              Larry "Doc" Sportello
# 1                         54  Herbert H. Heebert - Mama Heebert
# 2                         39                   Dr. Alfred Jones
# 3                         17                      Kenjiro Sanga
# 4                         42                        Jack Meehan
# ...                      ...                                ...
# 15533                     46                         Bo Barrett
# 15534                     15                             Ganesh
# 15535                     53              Detective Simon Perez
# 15536                     38                            Bahadur
# 15537                     28                          Tom Hoxey
#
#       max_weight_edge_target
# 0                  Sortilège
# 1                      Katie
# 2             Bernard Sugden
# 3      Andrew 'Drew' Collins
# 4              Martin Fallon
# ...                      ...
# 15533            Upscale Man
# 15534                  Mahat
# 15535                   Turk
# 15536         Ashok R. Rilak
# 15537                 Darwin
#
# [15538 rows x 12 columns]

# %%
# convert dataframe to csv

social_network_df.to_csv('./datasets/social_network_attributes_dataset.csv')
